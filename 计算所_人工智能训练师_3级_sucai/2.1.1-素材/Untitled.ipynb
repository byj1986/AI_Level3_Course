# %%
# -*- coding:utf-8 -*-
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = '/System/Library/Fonts/simhei222.ttf'
my_font = fm.FontProperties(fname=font_path)

# %%
my_font
